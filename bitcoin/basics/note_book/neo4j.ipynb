# %%
from neo4j import GraphDatabase

# %%
class WalletDB(object):

    def __init__(self, uri, user, password):
        self._driver = GraphDatabase.driver(uri, auth=(user, password), encrypted=False)#REVISE LATER FOR ENCRYPTION!!!

    def close(self):
        self._driver.close()
        
        
    @staticmethod
    def _new_address(tx, address,i,change_addr):
        if change_addr: addr_type = "change"
        else: addr_type = "recipient"
        result = tx.run("CREATE a = (:address {address:$address, acc_index:$index, type:$kind, created:timestamp()}) "
                        "RETURN a ", address=address, index = i, kind = addr_type)
        return result.single()
    
    
    @staticmethod
    def _new_utxo(tx, address,tx_id,out_index):
        local_index = tx.run( "MATCH (u:utxo) RETURN COUNT (u) ").single()[0] 
        result = tx.run("MATCH (n:address {address : $address}) "
                        "CREATE p = (:utxo {address:$address, transaction_id:$tx_id, out_index:$out_index, local_index:$local_index, spent:false})-[:BELONGS]->(n) "
                        "RETURN p ", address=address, tx_id = tx_id, out_index = out_index, local_index=local_index)
        return result.single()
    
    
    @staticmethod
    def _new_tx(tx,tx_id,inputs, outputs):
        result = tx.run("CREATE (n:TxOut {id:$tx_id, inputs:$inputs , outputs:$outputs, confirmations:0, created:timestamp()}) "
                        "WITH n "
                        "UNWIND n.inputs AS ins "
                        "MATCH coins = (:utxo {local_index:ins}) "
                        "FOREACH ( coin IN nodes(coins) | CREATE (coin)<-[:SPENT]-(n) ) ",
                        tx_id=tx_id, inputs = inputs, outputs = outputs)
        return result.single()
    
    
    @staticmethod
    def _update_confirmations(tx,tx_id,n_confirmations):
        result = tx.run("MATCH (n:TxOut {id:$tx_id}) "
                        "SET n.confirmations=$n_confirmations "
                        "RETURN n ", tx_id=tx_id, n_confirmations = n_confirmations)
        return result.single()
    
    
    @staticmethod
    def _update_utxo(tx,tx_id):
        result = tx.run("MATCH p = (u)<-[:SPENT]-(:TxOut {id:$tx_id}) "
                        "SET u.spent=true "
                        "RETURN p ", tx_id=tx_id)
        return result.consume()
    
    
    @staticmethod
    def _clean_addresses(tx):
        result = tx.run("MATCH (a: address) "
                        "WHERE NOT (a)--() AND (timestamp() - a.created )>2592000000 "
                        "DELETE a ")
        return result.single()

    
    @staticmethod
    def _look_for_coins(tx):
        result = tx.run("MATCH (coin:utxo {spent:false}) "
                        "RETURN coin.transaction_id, coin.out_index, coin.address ")
        return result.data()
    
    @staticmethod
    def _get_unused_addresses(tx):
        result = tx.run("MATCH (unused_address:address) "
                        "WHERE NOT (unused_address)--() "
                        "RETURN  unused_address.address, unused_address.acc_index, unused_address.type ")
        return result.data()
    
    @staticmethod
    def _run_as_system(tx):
        tx.run(":use system RETURN a")
        


    
    def new_address(self, address,i,change_addr):
        with self._driver.session() as session:
            result = session.write_transaction(self._new_address, address,i,change_addr)
            print(result)
            
    def new_utxo(self, address,tx_id,out_index):
        with self._driver.session() as session:
            result = session.write_transaction(self._new_utxo, address,tx_id,out_index)
            print(result)
            
    def new_tx(self, tx_id,utxo_local_index_list, outputs):
        with self._driver.session() as session:
            result = session.write_transaction(self._new_tx, tx_id,utxo_local_index_list, outputs)
            print(result)
            
    def update_confirmations(self, tx_id,n_confirmations):
        with self._driver.session() as session:
            result = session.write_transaction(self._update_confirmations, tx_id,n_confirmations)
            print(result)
            
    def update_utxo(self, tx_id):
        with self._driver.session() as session:
            result = session.write_transaction(self._update_utxo, tx_id)
            print(result)
        
    def clean_addresses(self):
        with self._driver.session() as session:
            result = session.write_transaction(self._clean_addresses)
            print(result)
            
    def look_for_coins(self):
        with self._driver.session() as session:
            result = session.write_transaction(self._look_for_coins)
            return result
        
    def get_unused_addresses(self):
        with self._driver.session() as session:
            result = session.write_transaction(self._get_unused_addresses)
            return result
        
    def run_as_system(self):
        with self._driver.session() as session:
            session.write_transaction(self._run_as_system)

# %%
db = WalletDB( "neo4j://localhost:7687" , "neo4j" , "wallet" )
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-5-f299bb86f849> in <module>
# ----> 1 db = WalletDB( "neo4j://localhost:7687" , "neo4j" , "wallet" )
#
# <ipython-input-4-b751e86ebe20> in __init__(self, uri, user, password)
#       2
#       3     def __init__(self, uri, user, password):
# ----> 4         self._driver = GraphDatabase.driver(uri, auth=(user, password), encrypted=True)#REVISE LATER FOR ENCRYPTION!!!
#       5
#       6     def close(self):
#
# /anaconda3/envs/mlenv/lib/python3.7/site-packages/neo4j/__init__.py in driver(cls, uri, **config)
#     118         :class:`.Driver` subclass instance directly.
#     119         """
# --> 120         return Driver(uri, **config)
#     121
#     122
#
# /anaconda3/envs/mlenv/lib/python3.7/site-packages/neo4j/__init__.py in __new__(cls, uri, **config)
#     159         for subclass in Driver.__subclasses__():
#     160             if parsed_scheme in subclass.uri_schemes:
# --> 161                 return subclass(uri, **config)
#     162         raise ValueError("URI scheme %r not supported" % parsed.scheme)
#     163
#
# /anaconda3/envs/mlenv/lib/python3.7/site-packages/neo4j/__init__.py in __new__(cls, uri, **config)
#     276         pool = RoutingConnectionPool(connector, initial_address, routing_context, initial_address, **config)
#     277         try:
# --> 278             pool.update_routing_table()
#     279         except:
#     280             pool.close()
#
# /anaconda3/envs/mlenv/lib/python3.7/site-packages/neobolt/routing.py in update_routing_table(self)
#     373                 return
#     374
# --> 375         if self.update_routing_table_from(*existing_routers):
#     376             return
#     377
#
# /anaconda3/envs/mlenv/lib/python3.7/site-packages/neobolt/routing.py in update_routing_table_from(self, *routers)
#     352                   "{}".format(", ".join(map(repr, routers))))
#     353         for router in routers:
# --> 354             new_routing_table = self.fetch_routing_table(router)
#     355             if new_routing_table is not None:
#     356                 self.routing_table.update(new_routing_table)
#
# /anaconda3/envs/mlenv/lib/python3.7/site-packages/neobolt/routing.py in fetch_routing_table(self, address)
#     317         :raise ProtocolError: if the routing information received is unusable
#     318         """
# --> 319         new_routing_info = self.fetch_routing_info(address)
#     320         if new_routing_info is None:
#     321             return None
#
# /anaconda3/envs/mlenv/lib/python3.7/site-packages/neobolt/routing.py in fetch_routing_info(self, address)
#     291
#     292         try:
# --> 293             with self.acquire_direct(address) as cx:
#     294                 _, _, server_version = (cx.server.agent or "").partition("/")
#     295                 if server_version and Version.parse(server_version) >= Version((3, 2)):
#
# /anaconda3/envs/mlenv/lib/python3.7/site-packages/neobolt/direct.py in acquire_direct(self, address)
#     606                 if can_create_new_connection:
#     607                     try:
# --> 608                         connection = self.connector(address, error_handler=self.connection_error_handler)
#     609                     except ServiceUnavailable:
#     610                         self.remove(address)
#
# /anaconda3/envs/mlenv/lib/python3.7/site-packages/neo4j/__init__.py in connector(address, **kwargs)
#     272
#     273         def connector(address, **kwargs):
# --> 274             return connect(address, **dict(config, **kwargs))
#     275
#     276         pool = RoutingConnectionPool(connector, initial_address, routing_context, initial_address, **config)
#
# /anaconda3/envs/mlenv/lib/python3.7/site-packages/neobolt/direct.py in connect(address, **config)
#     970         raise ServiceUnavailable("Failed to resolve addresses for %s" % address)
#     971     else:
# --> 972         raise last_error
#
# /anaconda3/envs/mlenv/lib/python3.7/site-packages/neobolt/direct.py in connect(address, **config)
#     961             host = address[0]
#     962             s = _connect(resolved_address, **config)
# --> 963             s, der_encoded_server_certificate = _secure(s, host, security_plan.ssl_context, **config)
#     964             connection = _handshake(s, address, der_encoded_server_certificate, **config)
#     965         except Exception as error:
#
# /anaconda3/envs/mlenv/lib/python3.7/site-packages/neobolt/direct.py in _secure(s, host, ssl_context, **config)
#     852         log_debug("[#%04X]  C: <SECURE> %s", local_port, host)
#     853         try:
# --> 854             s = ssl_context.wrap_socket(s, server_hostname=host if HAS_SNI and host else None)
#     855         except SSLError as cause:
#     856             s.close()
#
# /anaconda3/envs/mlenv/lib/python3.7/ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     421             server_hostname=server_hostname,
#     422             context=self,
# --> 423             session=session
#     424         )
#     425
#
# /anaconda3/envs/mlenv/lib/python3.7/ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#     868                         # non-blocking
#     869                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# --> 870                     self.do_handshake()
#     871             except (OSError, ValueError):
#     872                 self.close()
#
# /anaconda3/envs/mlenv/lib/python3.7/ssl.py in do_handshake(self, block)
#    1137             if timeout == 0.0 and block:
#    1138                 self.settimeout(None)
# -> 1139             self._sslobj.do_handshake()
#    1140         finally:
#    1141             self.settimeout(timeout)
#
# OSError: [Errno 0] Error

# %%
db.new_address("test_address1",0,False)
db.new_address("test_address2",777,False)
db.new_address("test_address3",22222,False)
db.new_address("test_address4",92747,True)
db.new_address("test_address5",99199191,True)
db.new_address("test_address6",666,True)
db.new_address("test_address7",625,True)
# Out:
# <Record a=<Path start=<Node id=14 labels={'address'} properties={'address': 'test_address1', 'type': 'recipient', 'acc_index': 0, 'created': 1586244466132}> end=<Node id=14 labels={'address'} properties={'address': 'test_address1', 'type': 'recipient', 'acc_index': 0, 'created': 1586244466132}> size=0>>
# <Record a=<Path start=<Node id=15 labels={'address'} properties={'address': 'test_address2', 'type': 'recipient', 'acc_index': 777, 'created': 1586244466145}> end=<Node id=15 labels={'address'} properties={'address': 'test_address2', 'type': 'recipient', 'acc_index': 777, 'created': 1586244466145}> size=0>>
# <Record a=<Path start=<Node id=0 labels={'address'} properties={'address': 'test_address3', 'type': 'recipient', 'acc_index': 22222, 'created': 1586244466152}> end=<Node id=0 labels={'address'} properties={'address': 'test_address3', 'type': 'recipient', 'acc_index': 22222, 'created': 1586244466152}> size=0>>
# <Record a=<Path start=<Node id=8 labels={'address'} properties={'address': 'test_address4', 'type': 'change', 'acc_index': 92747, 'created': 1586244466161}> end=<Node id=8 labels={'address'} properties={'address': 'test_address4', 'type': 'change', 'acc_index': 92747, 'created': 1586244466161}> size=0>>
# <Record a=<Path start=<Node id=2 labels={'address'} properties={'address': 'test_address5', 'type': 'change', 'acc_index': 99199191, 'created': 1586244466169}> end=<Node id=2 labels={'address'} properties={'address': 'test_address5', 'type': 'change', 'acc_index': 99199191, 'created': 1586244466169}> size=0>>
# <Record a=<Path start=<Node id=3 labels={'address'} properties={'address': 'test_address6', 'type': 'change', 'acc_index': 666, 'created': 1586244466181}> end=<Node id=3 labels={'address'} properties={'address': 'test_address6', 'type': 'change', 'acc_index': 666, 'created': 1586244466181}> size=0>>
# <Record a=<Path start=<Node id=5 labels={'address'} properties={'address': 'test_address7', 'type': 'change', 'acc_index': 625, 'created': 1586244466188}> end=<Node id=5 labels={'address'} properties={'address': 'test_address7', 'type': 'change', 'acc_index': 625, 'created': 1586244466188}> size=0>>

# %%
db.new_utxo("test_address1",1000,2)
db.new_utxo("test_address2",1001,0)
db.new_utxo("test_address3",1002,1)
db.new_utxo("test_address4",1003,8)
db.new_utxo("test_address5",1004,5)
# Out:
# <Record p=<Path start=<Node id=6 labels={'utxo'} properties={'transaction_id': 1000, 'out_index': 2, 'local_index': 0, 'address': 'test_address1', 'spent': False}> end=<Node id=14 labels={'address'} properties={'address': 'test_address1', 'type': 'recipient', 'created': 1586244466132, 'acc_index': 0}> size=1>>
# <Record p=<Path start=<Node id=7 labels={'utxo'} properties={'transaction_id': 1001, 'out_index': 0, 'local_index': 1, 'address': 'test_address2', 'spent': False}> end=<Node id=15 labels={'address'} properties={'address': 'test_address2', 'type': 'recipient', 'created': 1586244466145, 'acc_index': 777}> size=1>>
# <Record p=<Path start=<Node id=9 labels={'utxo'} properties={'transaction_id': 1002, 'out_index': 1, 'local_index': 2, 'address': 'test_address3', 'spent': False}> end=<Node id=0 labels={'address'} properties={'address': 'test_address3', 'type': 'recipient', 'created': 1586244466152, 'acc_index': 22222}> size=1>>
# <Record p=<Path start=<Node id=10 labels={'utxo'} properties={'transaction_id': 1003, 'out_index': 8, 'local_index': 3, 'address': 'test_address4', 'spent': False}> end=<Node id=8 labels={'address'} properties={'address': 'test_address4', 'type': 'change', 'created': 1586244466161, 'acc_index': 92747}> size=1>>
# <Record p=<Path start=<Node id=11 labels={'utxo'} properties={'transaction_id': 1004, 'out_index': 5, 'local_index': 4, 'address': 'test_address5', 'spent': False}> end=<Node id=2 labels={'address'} properties={'address': 'test_address5', 'type': 'change', 'created': 1586244466169, 'acc_index': 99199191}> size=1>>

# %%
db.new_tx(2222,[0,1], ["ouptut1","output2"])
# Out:
# None

# %%
db.update_confirmations(2222,7)
# Out:
# <Record n=<Node id=12 labels={'TxOut'} properties={'outputs': ['ouptut1', 'output2'], 'id': 2222, 'confirmations': 7, 'created': 1586244466250, 'inputs': [0, 1]}>>

# %%
up = db.update_utxo(2222)
# Out:
# <neo4j.BoltStatementResultSummary object at 0x114dffe90>

# %%
db.clean_addresses()
# Out:
# None

# %%
add = db.look_for_coins()

# %%
add
# Out:
# [{'coin.transaction_id': 1002,
#   'coin.out_index': 1,
#   'coin.address': 'test_address3'},
#  {'coin.transaction_id': 1003,
#   'coin.out_index': 8,
#   'coin.address': 'test_address4'},
#  {'coin.transaction_id': 1004,
#   'coin.out_index': 5,
#   'coin.address': 'test_address5'}]

# %%
unused_add = db.get_unused_addresses()
unused_add
# Out:
# [{'unused_address.address': 'test_address6',
#   'unused_address.acc_index': 666,
#   'unused_address.type': 'change'},
#  {'unused_address.address': 'test_address7',
#   'unused_address.acc_index': 625,
#   'unused_address.type': 'change'}]

# %%
driver = GraphDatabase.driver("neo4j://localhost:7687" , auth=("neo4j", "wallet"), encrypted=False)

# %%
import concurrent.futures
import threading
import time
import random

def write_block(i,file):
    time.sleep(0.005)
    print(f"wrote block {i} file {file}")
    
def write_tx(t,i,file):
    time.sleep(0.015)
    print(f"wrote transaction {t} for block {i} file {file}")

def parse_blockchain_demo(file):
    #db = BlockChainDB( "neo4j://localhost:7687" ,"neo4j" ,"wallet" )
    ok = True
    i = 0
    
    #while True:
        
    try:
        #with open(f"blocks_demo/blk{i:05}.dat","rb") as block_file:
        print(f"openning {file}")

        while ok:

            try:

                #read_file_and_parse_block
                time.sleep(0.005)
                print(f"parsed block {i} file {file}")

                write_block(i,file)

                for transaction in range(random.randint(1, 200)):
                    #read_file_and_parse_transaction
                    time.sleep(0.005)
                    print(f"parsed transaction {transaction} for block {i} file {file}")

                    write_tx(transaction,i, file)
                i+=1
                if i>=20: raise Exception

            except Exception as e:
                print(f"Finished blk{i:05} file. ")
                i+=1
                print(e)
                print(e.with_traceback)
                break
    except:
        print("Finsihed.")
        #break

    
def main():
    file_list = [f"blocks_demo/blk{i:05}.dat" for i in range(2)]
    with concurrent.futures.ThreadPoolExecutor(max_workers=2) as executor:
        executor.map(parse_blockchain_demo, file_list)

# %%
       
main()
# Out:
# openning blocks_demo/blk00000.dat
# openning blocks_demo/blk00001.dat
# parsed block 0 file blocks_demo/blk00000.datparsed block 0 file blocks_demo/blk00001.dat
#
# wrote block 0 file blocks_demo/blk00000.datwrote block 0 file blocks_demo/blk00001.dat
#
# parsed transaction 0 for block 0 file blocks_demo/blk00000.dat
# parsed transaction 0 for block 0 file blocks_demo/blk00001.dat
# wrote transaction 0 for block 0 file blocks_demo/blk00000.datwrote transaction 0 for block 0 file blocks_demo/blk00001.dat
#
# parsed transaction 1 for block 0 file blocks_demo/blk00001.datparsed transaction 1 for block 0 file blocks_demo/blk00000.dat
#
# wrote transaction 1 for block 0 file blocks_demo/blk00001.datwrote transaction 1 for block 0 file blocks_demo/blk00000.dat
#
# parsed transaction 2 for block 0 file blocks_demo/blk00000.datparsed transaction 2 for block 0 file blocks_demo/blk00001.dat
#
# wrote transaction 2 for block 0 file blocks_demo/blk00000.datwrote transaction 2 for block 0 file blocks_demo/blk00001.dat
#
# parsed transaction 3 for block 0 file blocks_demo/blk00000.dat
# parsed transaction 3 for block 0 file blocks_demo/blk00001.dat
# wrote transaction 3 for block 0 file blocks_demo/blk00000.datwrote transaction 3 for block 0 file blocks_demo/blk00001.dat
#
# parsed transaction 4 for block 0 file blocks_demo/blk00001.dat
# parsed transaction 4 for block 0 file blocks_demo/blk00000.dat
# wrote transaction 4 for block 0 file blocks_demo/blk00001.datwrote transaction 4 for block 0 file blocks_demo/blk00000.dat
#
# parsed transaction 5 for block 0 file blocks_demo/blk00001.datparsed transaction 5 for block 0 file blocks_demo/blk00000.dat
#
# wrote transaction 5 for block 0 file blocks_demo/blk00000.datwrote transaction 5 for block 0 file blocks_demo/blk00001.dat
#
# parsed transaction 6 for block 0 file blocks_demo/blk00001.datparsed transaction 6 for block 0 file blocks_demo/blk00000.dat
#
# wrote transaction 6 for block 0 file blocks_demo/blk00000.datwrote transaction 6 for block 0 file blocks_demo/blk00001.dat
#
# parsed transaction 7 for block 0 file blocks_demo/blk00001.dat
# parsed transaction 7 for block 0 file blocks_demo/blk00000.dat
# wrote transaction 7 for block 0 file blocks_demo/blk00001.datwrote transaction 7 for block 0 file blocks_demo/blk00000.dat
#
# parsed transaction 8 for block 0 file blocks_demo/blk00000.datparsed transaction 8 for block 0 file blocks_demo/blk00001.dat
#
# wrote transaction 8 for block 0 file blocks_demo/blk00001.datwrote transaction 8 for block 0 file blocks_demo/blk00000.dat
#
# parsed transaction 9 for block 0 file blocks_demo/blk00001.dat
# parsed transaction 9 for block 0 file blocks_demo/blk00000.dat
# wrote transaction 9 for block 0 file blocks_demo/blk00001.datwrote transaction 9 for block 0 file blocks_demo/blk00000.dat
#
# parsed transaction 10 for block 0 file blocks_demo/blk00000.datparsed block 1 file blocks_demo/blk00001.dat
#
# wrote block 1 file blocks_demo/blk00001.dat
# parsed transaction 0 for block 1 file blocks_demo/blk00001.dat
# wrote transaction 10 for block 0 file blocks_demo/blk00000.dat
# parsed transaction 11 for block 0 file blocks_demo/blk00000.dat
# wrote transaction 0 for block 1 file blocks_demo/blk00001.dat
# parsed transaction 1 for block 1 file blocks_demo/blk00001.dat
# wrote transaction 11 for block 0 file blocks_demo/blk00000.dat
# parsed transaction 12 for block 0 file blocks_demo/blk00000.dat
# wrote transaction 1 for block 1 file blocks_demo/blk00001.dat
# parsed transaction 2 for block 1 file blocks_demo/blk00001.dat
# wrote transaction 12 for block 0 file blocks_demo/blk00000.dat
# parsed transaction 13 for block 0 file blocks_demo/blk00000.dat
# wrote transaction 2 for block 1 file blocks_demo/blk00001.dat
# parsed transaction 3 for block 1 file blocks_demo/blk00001.dat
# wrote transaction 13 for block 0 file blocks_demo/blk00000.dat
# parsed transaction 14 for block 0 file blocks_demo/blk00000.dat
# wrote transaction 3 for block 1 file blocks_demo/blk00001.dat
# parsed transaction 4 for block 1 file blocks_demo/blk00001.dat
# wrote transaction 14 for block 0 file blocks_demo/blk00000.dat
# parsed transaction 15 for block 0 file blocks_demo/blk00000.dat
# wrote transaction 4 for block 1 file blocks_demo/blk00001.dat
# parsed transaction 5 for block 1 file blocks_demo/blk00001.dat
# wrote transaction 15 for block 0 file blocks_demo/blk00000.dat
# parsed transaction 16 for block 0 file blocks_demo/blk00000.dat
# wrote transaction 5 for block 1 file blocks_demo/blk00001.dat
# parsed transaction 6 for block 1 file blocks_demo/blk00001.dat
# wrote transaction 16 for block 0 file blocks_demo/blk00000.dat
# parsed transaction 17 for block 0 file blocks_demo/blk00000.dat
# wrote transaction 6 for block 1 file blocks_demo/blk00001.dat
# parsed transaction 7 for block 1 file blocks_demo/blk00001.dat
# wrote transaction 17 for block 0 file blocks_demo/blk00000.dat
# parsed transaction 18 for block 0 file blocks_demo/blk00000.dat
# wrote transaction 7 for block 1 file blocks_demo/blk00001.dat
# parsed transaction 8 for block 1 file blocks_demo/blk00001.dat
# wrote transaction 18 for block 0 file blocks_demo/blk00000.dat
# parsed transaction 19 for block 0 file blocks_demo/blk00000.dat
# wrote transaction 8 for block 1 file blocks_demo/blk00001.dat
# parsed transaction 9 for block 1 file blocks_demo/blk00001.dat
# wrote transaction 19 for block 0 file blocks_demo/blk00000.dat
# parsed transaction 20 for block 0 file blocks_demo/blk00000.dat
# wrote transaction 9 for block 1 file blocks_demo/blk00001.dat
# parsed transaction 10 for block 1 file blocks_demo/blk00001.dat
# wrote transaction 20 for block 0 file blocks_demo/blk00000.dat
# parsed transaction 21 for block 0 file blocks_demo/blk00000.dat
# wrote transaction 10 for block 1 file blocks_demo/blk00001.dat
# parsed transaction 11 for block 1 file blocks_demo/blk00001.dat
# wrote transaction 21 for block 0 file blocks_demo/blk00000.dat
# parsed transaction 22 for block 0 file blocks_demo/blk00000.dat
# wrote transaction 11 for block 1 file blocks_demo/blk00001.dat
# parsed transaction 12 for block 1 file blocks_demo/blk00001.dat
# wrote transaction 22 for block 0 file blocks_demo/blk00000.dat
# parsed transaction 23 for block 0 file blocks_demo/blk00000.dat
# wrote transaction 12 for block 1 file blocks_demo/blk00001.dat
# parsed transaction 13 for block 1 file blocks_demo/blk00001.dat
# wrote transaction 23 for block 0 file blocks_demo/blk00000.dat
# parsed transaction 24 for block 0 file blocks_demo/blk00000.dat
# wrote transaction 13 for block 1 file blocks_demo/blk00001.dat
# parsed transaction 14 for block 1 file blocks_demo/blk00001.dat
# wrote transaction 24 for block 0 file blocks_demo/blk00000.dat
# parsed transaction 25 for block 0 file blocks_demo/blk00000.dat
# wrote transaction 14 for block 1 file blocks_demo/blk00001.dat
# parsed transaction 15 for block 1 file blocks_demo/blk00001.dat
# wrote transaction 25 for block 0 file blocks_demo/blk00000.dat
# parsed transaction 26 for block 0 file blocks_demo/blk00000.dat
# wrote transaction 15 for block 1 file blocks_demo/blk00001.dat
# parsed transaction 16 for block 1 file blocks_demo/blk00001.dat
# wrote transaction 26 for block 0 file blocks_demo/blk00000.dat
# parsed transaction 27 for block 0 file blocks_demo/blk00000.dat
# wrote transaction 16 for block 1 file blocks_demo/blk00001.dat
# parsed transaction 17 for block 1 file blocks_demo/blk00001.dat
# wrote transaction 27 for block 0 file blocks_demo/blk00000.dat
# parsed transaction 28 for block 0 file blocks_demo/blk00000.dat
# wrote transaction 17 for block 1 file blocks_demo/blk00001.dat
# parsed transaction 18 for block 1 file blocks_demo/blk00001.dat
# wrote transaction 28 for block 0 file blocks_demo/blk00000.dat
# wrote transaction 18 for block 1 file blocks_demo/blk00001.dat
# parsed transaction 29 for block 0 file blocks_demo/blk00000.dat
# parsed transaction 19 for block 1 file blocks_demo/blk00001.dat
# wrote transaction 29 for block 0 file blocks_demo/blk00000.dat
# wrote transaction 19 for block 1 file blocks_demo/blk00001.dat
# parsed transaction 30 for block 0 file blocks_demo/blk00000.dat
# parsed transaction 20 for block 1 file blocks_demo/blk00001.dat
# wrote transaction 30 for block 0 file blocks_demo/blk00000.dat
# wrote transaction 20 for block 1 file blocks_demo/blk00001.dat
# parsed transaction 31 for block 0 file blocks_demo/blk00000.dat
# parsed transaction 21 for block 1 file blocks_demo/blk00001.dat
# wrote transaction 31 for block 0 file blocks_demo/blk00000.dat
# parsed transaction 32 for block 0 file blocks_demo/blk00000.datwrote transaction 21 for block 1 file blocks_demo/blk00001.dat
#
# parsed transaction 22 for block 1 file blocks_demo/blk00001.dat
# wrote transaction 32 for block 0 file blocks_demo/blk00000.dat
# wrote transaction 22 for block 1 file blocks_demo/blk00001.dat
# parsed transaction 33 for block 0 file blocks_demo/blk00000.dat
# parsed transaction 23 for block 1 file blocks_demo/blk00001.dat
# wrote transaction 33 for block 0 file blocks_demo/blk00000.dat
# wrote transaction 23 for block 1 file blocks_demo/blk00001.dat
# parsed transaction 34 for block 0 file blocks_demo/blk00000.dat
# parsed transaction 24 for block 1 file blocks_demo/blk00001.dat
# wrote transaction 34 for block 0 file blocks_demo/blk00000.datwrote transaction 24 for block 1 file blocks_demo/blk00001.dat
#
# parsed transaction 25 for block 1 file blocks_demo/blk00001.datparsed transaction 35 for block 0 file blocks_demo/blk00000.dat
#
# wrote transaction 35 for block 0 file blocks_demo/blk00000.datwrote transaction 25 for block 1 file blocks_demo/blk00001.dat
#
# parsed transaction 26 for block 1 file blocks_demo/blk00001.dat
# parsed transaction 36 for block 0 file blocks_demo/blk00000.dat
# wrote transaction 26 for block 1 file blocks_demo/blk00001.datwrote transaction 36 for block 0 file blocks_demo/blk00000.dat
#
# parsed transaction 27 for block 1 file blocks_demo/blk00001.datparsed transaction 37 for block 0 file blocks_demo/blk00000.dat
#
# wrote transaction 27 for block 1 file blocks_demo/blk00001.dat
# wrote transaction 37 for block 0 file blocks_demo/blk00000.dat
# parsed transaction 28 for block 1 file blocks_demo/blk00001.dat
# parsed transaction 38 for block 0 file blocks_demo/blk00000.dat
# wrote transaction 28 for block 1 file blocks_demo/blk00001.dat
# wrote transaction 38 for block 0 file blocks_demo/blk00000.dat
# parsed transaction 29 for block 1 file blocks_demo/blk00001.dat
# parsed transaction 39 for block 0 file blocks_demo/blk00000.dat
# wrote transaction 39 for block 0 file blocks_demo/blk00000.datwrote transaction 29 for block 1 file blocks_demo/blk00001.dat
#
# parsed transaction 40 for block 0 file blocks_demo/blk00000.dat
# parsed transaction 30 for block 1 file blocks_demo/blk00001.dat
# wrote transaction 40 for block 0 file blocks_demo/blk00000.dat
# wrote transaction 30 for block 1 file blocks_demo/blk00001.dat
# parsed transaction 41 for block 0 file blocks_demo/blk00000.dat
# parsed transaction 31 for block 1 file blocks_demo/blk00001.dat
# wrote transaction 41 for block 0 file blocks_demo/blk00000.dat
# wrote transaction 31 for block 1 file blocks_demo/blk00001.dat
# parsed transaction 42 for block 0 file blocks_demo/blk00000.dat
# parsed transaction 32 for block 1 file blocks_demo/blk00001.dat
# wrote transaction 42 for block 0 file blocks_demo/blk00000.datwrote transaction 32 for block 1 file blocks_demo/blk00001.dat
#
# parsed transaction 33 for block 1 file blocks_demo/blk00001.datparsed transaction 43 for block 0 file blocks_demo/blk00000.dat
#
# wrote transaction 43 for block 0 file blocks_demo/blk00000.datwrote transaction 33 for block 1 file blocks_demo/blk00001.dat
#
# parsed transaction 44 for block 0 file blocks_demo/blk00000.datparsed transaction 34 for block 1 file blocks_demo/blk00001.dat
#
# wrote transaction 44 for block 0 file blocks_demo/blk00000.datwrote transaction 34 for block 1 file blocks_demo/blk00001.dat
#
# parsed transaction 45 for block 0 file blocks_demo/blk00000.dat
# parsed transaction 35 for block 1 file blocks_demo/blk00001.dat
# wrote transaction 45 for block 0 file blocks_demo/blk00000.datwrote transaction 35 for block 1 file blocks_demo/blk00001.dat
#
# parsed transaction 46 for block 0 file blocks_demo/blk00000.datparsed transaction 36 for block 1 file blocks_demo/blk00001.dat
#
# wrote transaction 36 for block 1 file blocks_demo/blk00001.datwrote transaction 46 for block 0 file blocks_demo/blk00000.dat
#
# parsed transaction 47 for block 0 file blocks_demo/blk00000.datparsed transaction 37 for block 1 file blocks_demo/blk00001.dat
#
# wrote transaction 47 for block 0 file blocks_demo/blk00000.datwrote transaction 37 for block 1 file blocks_demo/blk00001.dat
#
# parsed transaction 38 for block 1 file blocks_demo/blk00001.dat
# parsed transaction 48 for block 0 file blocks_demo/blk00000.dat
# wrote transaction 38 for block 1 file blocks_demo/blk00001.dat
# wrote transaction 48 for block 0 file blocks_demo/blk00000.dat
# parsed transaction 39 for block 1 file blocks_demo/blk00001.dat
# parsed transaction 49 for block 0 file blocks_demo/blk00000.dat
# wrote transaction 39 for block 1 file blocks_demo/blk00001.dat
# wrote transaction 49 for block 0 file blocks_demo/blk00000.dat
# parsed transaction 40 for block 1 file blocks_demo/blk00001.dat
# parsed transaction 50 for block 0 file blocks_demo/blk00000.dat
# wrote transaction 40 for block 1 file blocks_demo/blk00001.dat
# wrote transaction 50 for block 0 file blocks_demo/blk00000.datparsed transaction 41 for block 1 file blocks_demo/blk00001.dat
#
# parsed transaction 51 for block 0 file blocks_demo/blk00000.dat
# wrote transaction 41 for block 1 file blocks_demo/blk00001.dat
# wrote transaction 51 for block 0 file blocks_demo/blk00000.dat
# parsed transaction 42 for block 1 file blocks_demo/blk00001.dat
# parsed transaction 52 for block 0 file blocks_demo/blk00000.dat
# wrote transaction 42 for block 1 file blocks_demo/blk00001.dat
# parsed transaction 43 for block 1 file blocks_demo/blk00001.dat
# wrote transaction 52 for block 0 file blocks_demo/blk00000.dat
# parsed transaction 53 for block 0 file blocks_demo/blk00000.dat
# wrote transaction 43 for block 1 file blocks_demo/blk00001.dat
# wrote transaction 53 for block 0 file blocks_demo/blk00000.dat
# parsed transaction 44 for block 1 file blocks_demo/blk00001.dat
# parsed transaction 54 for block 0 file blocks_demo/blk00000.dat
# wrote transaction 44 for block 1 file blocks_demo/blk00001.dat
# parsed transaction 45 for block 1 file blocks_demo/blk00001.datwrote transaction 54 for block 0 file blocks_demo/blk00000.dat
#
# parsed transaction 55 for block 0 file blocks_demo/blk00000.dat
# wrote transaction 45 for block 1 file blocks_demo/blk00001.dat
# parsed transaction 46 for block 1 file blocks_demo/blk00001.dat
# wrote transaction 55 for block 0 file blocks_demo/blk00000.dat
# parsed transaction 56 for block 0 file blocks_demo/blk00000.dat
# wrote transaction 46 for block 1 file blocks_demo/blk00001.dat
# wrote transaction 56 for block 0 file blocks_demo/blk00000.dat
# parsed transaction 47 for block 1 file blocks_demo/blk00001.dat
# parsed transaction 57 for block 0 file blocks_demo/blk00000.dat
# wrote transaction 47 for block 1 file blocks_demo/blk00001.dat
# wrote transaction 57 for block 0 file blocks_demo/blk00000.dat
# parsed transaction 48 for block 1 file blocks_demo/blk00001.dat
# parsed transaction 58 for block 0 file blocks_demo/blk00000.dat
# wrote transaction 48 for block 1 file blocks_demo/blk00001.dat
# parsed transaction 49 for block 1 file blocks_demo/blk00001.datwrote transaction 58 for block 0 file blocks_demo/blk00000.dat
#
# parsed transaction 59 for block 0 file blocks_demo/blk00000.dat
# wrote transaction 49 for block 1 file blocks_demo/blk00001.dat
# wrote transaction 59 for block 0 file blocks_demo/blk00000.dat
# parsed transaction 50 for block 1 file blocks_demo/blk00001.dat
# parsed transaction 60 for block 0 file blocks_demo/blk00000.dat
# wrote transaction 50 for block 1 file blocks_demo/blk00001.dat
# wrote transaction 60 for block 0 file blocks_demo/blk00000.dat
# parsed transaction 51 for block 1 file blocks_demo/blk00001.dat
# parsed transaction 61 for block 0 file blocks_demo/blk00000.dat
# wrote transaction 51 for block 1 file blocks_demo/blk00001.dat
# wrote transaction 61 for block 0 file blocks_demo/blk00000.dat
# parsed transaction 52 for block 1 file blocks_demo/blk00001.dat
# parsed transaction 62 for block 0 file blocks_demo/blk00000.dat
# wrote transaction 52 for block 1 file blocks_demo/blk00001.dat
# wrote transaction 62 for block 0 file blocks_demo/blk00000.dat
# parsed transaction 53 for block 1 file blocks_demo/blk00001.dat
# parsed transaction 63 for block 0 file blocks_demo/blk00000.dat
# wrote transaction 53 for block 1 file blocks_demo/blk00001.dat
# wrote transaction 63 for block 0 file blocks_demo/blk00000.dat
# parsed transaction 54 for block 1 file blocks_demo/blk00001.dat
# parsed transaction 64 for block 0 file blocks_demo/blk00000.dat
# wrote transaction 54 for block 1 file blocks_demo/blk00001.datwrote transaction 64 for block 0 file blocks_demo/blk00000.dat
#
# parsed transaction 65 for block 0 file blocks_demo/blk00000.datparsed transaction 55 for block 1 file blocks_demo/blk00001.dat
#
# wrote transaction 65 for block 0 file blocks_demo/blk00000.dat
# wrote transaction 55 for block 1 file blocks_demo/blk00001.dat
# parsed transaction 66 for block 0 file blocks_demo/blk00000.datparsed transaction 56 for block 1 file blocks_demo/blk00001.dat
#
# wrote transaction 56 for block 1 file blocks_demo/blk00001.dat
# wrote transaction 66 for block 0 file blocks_demo/blk00000.dat
# parsed block 1 file blocks_demo/blk00000.dat
# parsed transaction 57 for block 1 file blocks_demo/blk00001.dat
# wrote block 1 file blocks_demo/blk00000.dat
# parsed transaction 0 for block 1 file blocks_demo/blk00000.dat
# wrote transaction 57 for block 1 file blocks_demo/blk00001.dat
# parsed transaction 58 for block 1 file blocks_demo/blk00001.dat
# wrote transaction 0 for block 1 file blocks_demo/blk00000.dat
# parsed transaction 1 for block 1 file blocks_demo/blk00000.dat
# wrote transaction 58 for block 1 file blocks_demo/blk00001.dat
# parsed transaction 59 for block 1 file blocks_demo/blk00001.dat
# wrote transaction 1 for block 1 file blocks_demo/blk00000.dat
# parsed transaction 2 for block 1 file blocks_demo/blk00000.dat
# wrote transaction 59 for block 1 file blocks_demo/blk00001.dat
# parsed transaction 60 for block 1 file blocks_demo/blk00001.dat
# wrote transaction 2 for block 1 file blocks_demo/blk00000.dat
# parsed transaction 3 for block 1 file blocks_demo/blk00000.dat
# wrote transaction 60 for block 1 file blocks_demo/blk00001.dat
# parsed transaction 61 for block 1 file blocks_demo/blk00001.dat
# wrote transaction 3 for block 1 file blocks_demo/blk00000.dat
# parsed transaction 4 for block 1 file blocks_demo/blk00000.dat
# wrote transaction 61 for block 1 file blocks_demo/blk00001.dat
# parsed transaction 62 for block 1 file blocks_demo/blk00001.dat
# wrote transaction 4 for block 1 file blocks_demo/blk00000.dat
# parsed transaction 5 for block 1 file blocks_demo/blk00000.dat
# wrote transaction 62 for block 1 file blocks_demo/blk00001.dat
# parsed transaction 63 for block 1 file blocks_demo/blk00001.dat
# wrote transaction 5 for block 1 file blocks_demo/blk00000.dat
# parsed transaction 6 for block 1 file blocks_demo/blk00000.dat
# wrote transaction 63 for block 1 file blocks_demo/blk00001.dat
# wrote transaction 6 for block 1 file blocks_demo/blk00000.dat
# parsed transaction 64 for block 1 file blocks_demo/blk00001.dat
# parsed transaction 7 for block 1 file blocks_demo/blk00000.dat
# wrote transaction 64 for block 1 file blocks_demo/blk00001.dat
# wrote transaction 7 for block 1 file blocks_demo/blk00000.datparsed transaction 65 for block 1 file blocks_demo/blk00001.dat
#
# parsed transaction 8 for block 1 file blocks_demo/blk00000.dat
# wrote transaction 65 for block 1 file blocks_demo/blk00001.dat
# wrote transaction 8 for block 1 file blocks_demo/blk00000.dat
# parsed block 2 file blocks_demo/blk00001.dat
# parsed transaction 9 for block 1 file blocks_demo/blk00000.dat
# wrote block 2 file blocks_demo/blk00001.dat
# parsed transaction 0 for block 2 file blocks_demo/blk00001.dat
# wrote transaction 9 for block 1 file blocks_demo/blk00000.dat
# parsed transaction 10 for block 1 file blocks_demo/blk00000.dat
# wrote transaction 0 for block 2 file blocks_demo/blk00001.dat
# parsed transaction 1 for block 2 file blocks_demo/blk00001.dat
# wrote transaction 10 for block 1 file blocks_demo/blk00000.dat
# parsed transaction 11 for block 1 file blocks_demo/blk00000.dat
# wrote transaction 1 for block 2 file blocks_demo/blk00001.dat
# parsed transaction 2 for block 2 file blocks_demo/blk00001.dat
# wrote transaction 11 for block 1 file blocks_demo/blk00000.dat
# parsed transaction 12 for block 1 file blocks_demo/blk00000.dat
# wrote transaction 2 for block 2 file blocks_demo/blk00001.dat
# parsed transaction 3 for block 2 file blocks_demo/blk00001.dat
# wrote transaction 12 for block 1 file blocks_demo/blk00000.dat
# parsed transaction 13 for block 1 file blocks_demo/blk00000.dat
# wrote transaction 3 for block 2 file blocks_demo/blk00001.dat
# parsed transaction 4 for block 2 file blocks_demo/blk00001.dat
# wrote transaction 13 for block 1 file blocks_demo/blk00000.dat
# parsed transaction 14 for block 1 file blocks_demo/blk00000.dat
# wrote transaction 4 for block 2 file blocks_demo/blk00001.dat
# parsed transaction 5 for block 2 file blocks_demo/blk00001.dat
# wrote transaction 14 for block 1 file blocks_demo/blk00000.dat
# parsed transaction 15 for block 1 file blocks_demo/blk00000.dat
# wrote transaction 5 for block 2 file blocks_demo/blk00001.dat
# parsed transaction 6 for block 2 file blocks_demo/blk00001.dat
# wrote transaction 15 for block 1 file blocks_demo/blk00000.dat
# parsed transaction 16 for block 1 file blocks_demo/blk00000.dat
# wrote transaction 6 for block 2 file blocks_demo/blk00001.dat
# parsed transaction 7 for block 2 file blocks_demo/blk00001.dat
# wrote transaction 16 for block 1 file blocks_demo/blk00000.dat
# parsed transaction 17 for block 1 file blocks_demo/blk00000.dat
# wrote transaction 7 for block 2 file blocks_demo/blk00001.dat
# parsed transaction 8 for block 2 file blocks_demo/blk00001.dat
# wrote transaction 17 for block 1 file blocks_demo/blk00000.dat
# parsed transaction 18 for block 1 file blocks_demo/blk00000.dat
# wrote transaction 8 for block 2 file blocks_demo/blk00001.dat
# parsed transaction 9 for block 2 file blocks_demo/blk00001.dat
# wrote transaction 18 for block 1 file blocks_demo/blk00000.dat
# parsed transaction 19 for block 1 file blocks_demo/blk00000.dat
# wrote transaction 9 for block 2 file blocks_demo/blk00001.dat
# parsed transaction 10 for block 2 file blocks_demo/blk00001.dat
# wrote transaction 19 for block 1 file blocks_demo/blk00000.dat
# parsed transaction 20 for block 1 file blocks_demo/blk00000.dat
# wrote transaction 10 for block 2 file blocks_demo/blk00001.dat
# parsed transaction 11 for block 2 file blocks_demo/blk00001.dat
# wrote transaction 20 for block 1 file blocks_demo/blk00000.dat
# parsed transaction 21 for block 1 file blocks_demo/blk00000.dat
# wrote transaction 11 for block 2 file blocks_demo/blk00001.dat
# parsed transaction 12 for block 2 file blocks_demo/blk00001.dat
# wrote transaction 21 for block 1 file blocks_demo/blk00000.dat
# parsed transaction 22 for block 1 file blocks_demo/blk00000.dat
# wrote transaction 12 for block 2 file blocks_demo/blk00001.dat
# parsed transaction 13 for block 2 file blocks_demo/blk00001.dat
# wrote transaction 22 for block 1 file blocks_demo/blk00000.dat
# parsed transaction 23 for block 1 file blocks_demo/blk00000.dat
# wrote transaction 13 for block 2 file blocks_demo/blk00001.dat
# parsed block 3 file blocks_demo/blk00001.dat
# wrote transaction 23 for block 1 file blocks_demo/blk00000.dat
# wrote block 3 file blocks_demo/blk00001.dat
# parsed transaction 24 for block 1 file blocks_demo/blk00000.dat
# parsed transaction 0 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 24 for block 1 file blocks_demo/blk00000.dat
# wrote transaction 0 for block 3 file blocks_demo/blk00001.dat
# parsed transaction 25 for block 1 file blocks_demo/blk00000.datparsed transaction 1 for block 3 file blocks_demo/blk00001.dat
#
# wrote transaction 1 for block 3 file blocks_demo/blk00001.datwrote transaction 25 for block 1 file blocks_demo/blk00000.dat
#
# parsed transaction 2 for block 3 file blocks_demo/blk00001.datparsed transaction 26 for block 1 file blocks_demo/blk00000.dat
#
# wrote transaction 26 for block 1 file blocks_demo/blk00000.datwrote transaction 2 for block 3 file blocks_demo/blk00001.dat
#
# parsed transaction 27 for block 1 file blocks_demo/blk00000.datparsed transaction 3 for block 3 file blocks_demo/blk00001.dat
#
# wrote transaction 3 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 27 for block 1 file blocks_demo/blk00000.dat
# parsed transaction 4 for block 3 file blocks_demo/blk00001.dat
# parsed transaction 28 for block 1 file blocks_demo/blk00000.dat
# wrote transaction 4 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 28 for block 1 file blocks_demo/blk00000.dat
# parsed transaction 5 for block 3 file blocks_demo/blk00001.dat
# parsed block 2 file blocks_demo/blk00000.dat
# wrote block 2 file blocks_demo/blk00000.dat
# parsed transaction 0 for block 2 file blocks_demo/blk00000.dat
# wrote transaction 5 for block 3 file blocks_demo/blk00001.dat
# parsed transaction 6 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 0 for block 2 file blocks_demo/blk00000.dat
# parsed transaction 1 for block 2 file blocks_demo/blk00000.dat
# wrote transaction 6 for block 3 file blocks_demo/blk00001.dat
# parsed transaction 7 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 1 for block 2 file blocks_demo/blk00000.dat
# parsed transaction 2 for block 2 file blocks_demo/blk00000.datwrote transaction 7 for block 3 file blocks_demo/blk00001.dat
#
# parsed transaction 8 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 2 for block 2 file blocks_demo/blk00000.dat
# wrote transaction 8 for block 3 file blocks_demo/blk00001.dat
# parsed transaction 3 for block 2 file blocks_demo/blk00000.dat
# parsed transaction 9 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 3 for block 2 file blocks_demo/blk00000.dat
# parsed transaction 4 for block 2 file blocks_demo/blk00000.dat
# wrote transaction 9 for block 3 file blocks_demo/blk00001.dat
# parsed transaction 10 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 4 for block 2 file blocks_demo/blk00000.dat
# parsed transaction 5 for block 2 file blocks_demo/blk00000.dat
# wrote transaction 10 for block 3 file blocks_demo/blk00001.dat
# parsed transaction 11 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 5 for block 2 file blocks_demo/blk00000.dat
# parsed transaction 6 for block 2 file blocks_demo/blk00000.dat
# wrote transaction 11 for block 3 file blocks_demo/blk00001.dat
# parsed transaction 12 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 6 for block 2 file blocks_demo/blk00000.dat
# parsed transaction 7 for block 2 file blocks_demo/blk00000.dat
# wrote transaction 12 for block 3 file blocks_demo/blk00001.dat
# parsed transaction 13 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 7 for block 2 file blocks_demo/blk00000.dat
# parsed transaction 8 for block 2 file blocks_demo/blk00000.datwrote transaction 13 for block 3 file blocks_demo/blk00001.dat
#
# parsed transaction 14 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 8 for block 2 file blocks_demo/blk00000.dat
# parsed transaction 9 for block 2 file blocks_demo/blk00000.datwrote transaction 14 for block 3 file blocks_demo/blk00001.dat
#
# parsed transaction 15 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 9 for block 2 file blocks_demo/blk00000.dat
# parsed transaction 10 for block 2 file blocks_demo/blk00000.datwrote transaction 15 for block 3 file blocks_demo/blk00001.dat
#
# parsed transaction 16 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 10 for block 2 file blocks_demo/blk00000.dat
# wrote transaction 16 for block 3 file blocks_demo/blk00001.datparsed transaction 11 for block 2 file blocks_demo/blk00000.dat
#
# parsed transaction 17 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 11 for block 2 file blocks_demo/blk00000.dat
# wrote transaction 17 for block 3 file blocks_demo/blk00001.dat
# parsed transaction 12 for block 2 file blocks_demo/blk00000.dat
# parsed transaction 18 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 12 for block 2 file blocks_demo/blk00000.dat
# parsed transaction 13 for block 2 file blocks_demo/blk00000.datwrote transaction 18 for block 3 file blocks_demo/blk00001.dat
#
# parsed transaction 19 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 13 for block 2 file blocks_demo/blk00000.dat
# wrote transaction 19 for block 3 file blocks_demo/blk00001.dat
# parsed transaction 14 for block 2 file blocks_demo/blk00000.dat
# parsed transaction 20 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 14 for block 2 file blocks_demo/blk00000.dat
# wrote transaction 20 for block 3 file blocks_demo/blk00001.dat
# parsed transaction 15 for block 2 file blocks_demo/blk00000.dat
# parsed transaction 21 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 15 for block 2 file blocks_demo/blk00000.dat
# parsed transaction 16 for block 2 file blocks_demo/blk00000.dat
# wrote transaction 21 for block 3 file blocks_demo/blk00001.dat
# parsed transaction 22 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 16 for block 2 file blocks_demo/blk00000.dat
# wrote transaction 22 for block 3 file blocks_demo/blk00001.dat
# parsed transaction 17 for block 2 file blocks_demo/blk00000.dat
# parsed transaction 23 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 23 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 17 for block 2 file blocks_demo/blk00000.dat
# parsed transaction 24 for block 3 file blocks_demo/blk00001.datparsed transaction 18 for block 2 file blocks_demo/blk00000.dat
#
# wrote transaction 24 for block 3 file blocks_demo/blk00001.datwrote transaction 18 for block 2 file blocks_demo/blk00000.dat
#
# parsed transaction 19 for block 2 file blocks_demo/blk00000.datparsed transaction 25 for block 3 file blocks_demo/blk00001.dat
#
# wrote transaction 25 for block 3 file blocks_demo/blk00001.datwrote transaction 19 for block 2 file blocks_demo/blk00000.dat
#
# parsed transaction 26 for block 3 file blocks_demo/blk00001.dat
# parsed transaction 20 for block 2 file blocks_demo/blk00000.dat
# wrote transaction 26 for block 3 file blocks_demo/blk00001.datwrote transaction 20 for block 2 file blocks_demo/blk00000.dat
#
# parsed transaction 27 for block 3 file blocks_demo/blk00001.dat
# parsed transaction 21 for block 2 file blocks_demo/blk00000.dat
# wrote transaction 21 for block 2 file blocks_demo/blk00000.datwrote transaction 27 for block 3 file blocks_demo/blk00001.dat
#
# parsed transaction 22 for block 2 file blocks_demo/blk00000.dat
# parsed transaction 28 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 22 for block 2 file blocks_demo/blk00000.datwrote transaction 28 for block 3 file blocks_demo/blk00001.dat
#
# parsed transaction 29 for block 3 file blocks_demo/blk00001.datparsed transaction 23 for block 2 file blocks_demo/blk00000.dat
#
# wrote transaction 23 for block 2 file blocks_demo/blk00000.dat
# wrote transaction 29 for block 3 file blocks_demo/blk00001.dat
# parsed transaction 24 for block 2 file blocks_demo/blk00000.dat
# parsed transaction 30 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 24 for block 2 file blocks_demo/blk00000.dat
# wrote transaction 30 for block 3 file blocks_demo/blk00001.dat
# parsed transaction 25 for block 2 file blocks_demo/blk00000.dat
# parsed transaction 31 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 25 for block 2 file blocks_demo/blk00000.datwrote transaction 31 for block 3 file blocks_demo/blk00001.dat
#
# parsed transaction 26 for block 2 file blocks_demo/blk00000.datparsed transaction 32 for block 3 file blocks_demo/blk00001.dat
#
# wrote transaction 26 for block 2 file blocks_demo/blk00000.datwrote transaction 32 for block 3 file blocks_demo/blk00001.dat
#
# parsed transaction 27 for block 2 file blocks_demo/blk00000.datparsed transaction 33 for block 3 file blocks_demo/blk00001.dat
#
# wrote transaction 33 for block 3 file blocks_demo/blk00001.datwrote transaction 27 for block 2 file blocks_demo/blk00000.dat
#
# parsed transaction 34 for block 3 file blocks_demo/blk00001.datparsed transaction 28 for block 2 file blocks_demo/blk00000.dat
#
# wrote transaction 34 for block 3 file blocks_demo/blk00001.datwrote transaction 28 for block 2 file blocks_demo/blk00000.dat
#
# parsed transaction 35 for block 3 file blocks_demo/blk00001.datparsed transaction 29 for block 2 file blocks_demo/blk00000.dat
#
# wrote transaction 35 for block 3 file blocks_demo/blk00001.datwrote transaction 29 for block 2 file blocks_demo/blk00000.dat
#
# parsed transaction 30 for block 2 file blocks_demo/blk00000.dat
# parsed transaction 36 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 30 for block 2 file blocks_demo/blk00000.datwrote transaction 36 for block 3 file blocks_demo/blk00001.dat
#
# parsed transaction 37 for block 3 file blocks_demo/blk00001.dat
# parsed block 3 file blocks_demo/blk00000.dat
# wrote block 3 file blocks_demo/blk00000.dat
# parsed transaction 0 for block 3 file blocks_demo/blk00000.dat
# wrote transaction 37 for block 3 file blocks_demo/blk00001.dat
# parsed transaction 38 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 0 for block 3 file blocks_demo/blk00000.dat
# parsed transaction 1 for block 3 file blocks_demo/blk00000.dat
# wrote transaction 38 for block 3 file blocks_demo/blk00001.dat
# parsed transaction 39 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 1 for block 3 file blocks_demo/blk00000.dat
# parsed transaction 2 for block 3 file blocks_demo/blk00000.dat
# wrote transaction 39 for block 3 file blocks_demo/blk00001.dat
# parsed transaction 40 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 2 for block 3 file blocks_demo/blk00000.dat
# parsed transaction 3 for block 3 file blocks_demo/blk00000.dat
# wrote transaction 40 for block 3 file blocks_demo/blk00001.dat
# parsed transaction 41 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 3 for block 3 file blocks_demo/blk00000.dat
# parsed transaction 4 for block 3 file blocks_demo/blk00000.dat
# wrote transaction 41 for block 3 file blocks_demo/blk00001.dat
# parsed transaction 42 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 4 for block 3 file blocks_demo/blk00000.dat
# parsed transaction 5 for block 3 file blocks_demo/blk00000.dat
# wrote transaction 42 for block 3 file blocks_demo/blk00001.dat
# parsed transaction 43 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 5 for block 3 file blocks_demo/blk00000.dat
# parsed transaction 6 for block 3 file blocks_demo/blk00000.dat
# wrote transaction 43 for block 3 file blocks_demo/blk00001.dat
# parsed transaction 44 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 6 for block 3 file blocks_demo/blk00000.dat
# parsed transaction 7 for block 3 file blocks_demo/blk00000.dat
# wrote transaction 44 for block 3 file blocks_demo/blk00001.dat
# parsed transaction 45 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 7 for block 3 file blocks_demo/blk00000.dat
# parsed transaction 8 for block 3 file blocks_demo/blk00000.dat
# wrote transaction 45 for block 3 file blocks_demo/blk00001.dat
# parsed transaction 46 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 8 for block 3 file blocks_demo/blk00000.dat
# parsed transaction 9 for block 3 file blocks_demo/blk00000.dat
# wrote transaction 46 for block 3 file blocks_demo/blk00001.dat
# parsed transaction 47 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 9 for block 3 file blocks_demo/blk00000.dat
# parsed transaction 10 for block 3 file blocks_demo/blk00000.dat
# wrote transaction 47 for block 3 file blocks_demo/blk00001.dat
# parsed transaction 48 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 10 for block 3 file blocks_demo/blk00000.dat
# wrote transaction 48 for block 3 file blocks_demo/blk00001.datparsed transaction 11 for block 3 file blocks_demo/blk00000.dat
#
# parsed transaction 49 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 11 for block 3 file blocks_demo/blk00000.dat
# wrote transaction 49 for block 3 file blocks_demo/blk00001.dat
# parsed transaction 12 for block 3 file blocks_demo/blk00000.dat
# parsed transaction 50 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 12 for block 3 file blocks_demo/blk00000.dat
# wrote transaction 50 for block 3 file blocks_demo/blk00001.dat
# parsed transaction 13 for block 3 file blocks_demo/blk00000.dat
# parsed transaction 51 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 13 for block 3 file blocks_demo/blk00000.dat
# wrote transaction 51 for block 3 file blocks_demo/blk00001.datparsed transaction 14 for block 3 file blocks_demo/blk00000.dat
#
# parsed transaction 52 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 14 for block 3 file blocks_demo/blk00000.dat
# parsed transaction 15 for block 3 file blocks_demo/blk00000.datwrote transaction 52 for block 3 file blocks_demo/blk00001.dat
#
# parsed transaction 53 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 15 for block 3 file blocks_demo/blk00000.dat
# parsed transaction 16 for block 3 file blocks_demo/blk00000.dat
# wrote transaction 53 for block 3 file blocks_demo/blk00001.dat
# parsed transaction 54 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 16 for block 3 file blocks_demo/blk00000.dat
# parsed transaction 17 for block 3 file blocks_demo/blk00000.dat
# wrote transaction 54 for block 3 file blocks_demo/blk00001.dat
# parsed transaction 55 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 17 for block 3 file blocks_demo/blk00000.dat
# wrote transaction 55 for block 3 file blocks_demo/blk00001.datparsed transaction 18 for block 3 file blocks_demo/blk00000.dat
#
# parsed transaction 56 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 18 for block 3 file blocks_demo/blk00000.dat
# wrote transaction 56 for block 3 file blocks_demo/blk00001.dat
# parsed transaction 19 for block 3 file blocks_demo/blk00000.dat
# parsed transaction 57 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 19 for block 3 file blocks_demo/blk00000.dat
# wrote transaction 57 for block 3 file blocks_demo/blk00001.dat
# parsed transaction 20 for block 3 file blocks_demo/blk00000.dat
# parsed transaction 58 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 20 for block 3 file blocks_demo/blk00000.dat
# wrote transaction 58 for block 3 file blocks_demo/blk00001.dat
# parsed transaction 21 for block 3 file blocks_demo/blk00000.dat
# parsed transaction 59 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 21 for block 3 file blocks_demo/blk00000.datwrote transaction 59 for block 3 file blocks_demo/blk00001.dat
#
# parsed transaction 60 for block 3 file blocks_demo/blk00001.dat
# parsed transaction 22 for block 3 file blocks_demo/blk00000.dat
# wrote transaction 60 for block 3 file blocks_demo/blk00001.datwrote transaction 22 for block 3 file blocks_demo/blk00000.dat
#
# parsed transaction 23 for block 3 file blocks_demo/blk00000.dat
# parsed transaction 61 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 23 for block 3 file blocks_demo/blk00000.dat
# wrote transaction 61 for block 3 file blocks_demo/blk00001.dat
# parsed transaction 24 for block 3 file blocks_demo/blk00000.datparsed transaction 62 for block 3 file blocks_demo/blk00001.dat
#
# wrote transaction 24 for block 3 file blocks_demo/blk00000.dat
# wrote transaction 62 for block 3 file blocks_demo/blk00001.dat
# parsed transaction 25 for block 3 file blocks_demo/blk00000.dat
# parsed transaction 63 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 25 for block 3 file blocks_demo/blk00000.datwrote transaction 63 for block 3 file blocks_demo/blk00001.dat
#
# parsed transaction 64 for block 3 file blocks_demo/blk00001.datparsed transaction 26 for block 3 file blocks_demo/blk00000.dat
#
# wrote transaction 64 for block 3 file blocks_demo/blk00001.datwrote transaction 26 for block 3 file blocks_demo/blk00000.dat
#
# parsed transaction 65 for block 3 file blocks_demo/blk00001.dat
# parsed transaction 27 for block 3 file blocks_demo/blk00000.dat
# wrote transaction 65 for block 3 file blocks_demo/blk00001.datwrote transaction 27 for block 3 file blocks_demo/blk00000.dat
#
# parsed transaction 28 for block 3 file blocks_demo/blk00000.datparsed transaction 66 for block 3 file blocks_demo/blk00001.dat
#
# wrote transaction 66 for block 3 file blocks_demo/blk00001.datwrote transaction 28 for block 3 file blocks_demo/blk00000.dat
#
# parsed transaction 67 for block 3 file blocks_demo/blk00001.dat
# parsed transaction 29 for block 3 file blocks_demo/blk00000.dat
# wrote transaction 67 for block 3 file blocks_demo/blk00001.datwrote transaction 29 for block 3 file blocks_demo/blk00000.dat
#
# parsed transaction 68 for block 3 file blocks_demo/blk00001.dat
# parsed transaction 30 for block 3 file blocks_demo/blk00000.dat
# wrote transaction 68 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 30 for block 3 file blocks_demo/blk00000.dat
# parsed transaction 69 for block 3 file blocks_demo/blk00001.dat
# parsed transaction 31 for block 3 file blocks_demo/blk00000.dat
# wrote transaction 69 for block 3 file blocks_demo/blk00001.datwrote transaction 31 for block 3 file blocks_demo/blk00000.dat
#
# parsed transaction 32 for block 3 file blocks_demo/blk00000.datparsed transaction 70 for block 3 file blocks_demo/blk00001.dat
#
# wrote transaction 32 for block 3 file blocks_demo/blk00000.dat
# wrote transaction 70 for block 3 file blocks_demo/blk00001.dat
# parsed transaction 33 for block 3 file blocks_demo/blk00000.dat
# parsed transaction 71 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 33 for block 3 file blocks_demo/blk00000.dat
# wrote transaction 71 for block 3 file blocks_demo/blk00001.dat
# parsed transaction 34 for block 3 file blocks_demo/blk00000.dat
# parsed transaction 72 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 34 for block 3 file blocks_demo/blk00000.dat
# wrote transaction 72 for block 3 file blocks_demo/blk00001.dat
# parsed transaction 35 for block 3 file blocks_demo/blk00000.dat
# parsed transaction 73 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 35 for block 3 file blocks_demo/blk00000.datwrote transaction 73 for block 3 file blocks_demo/blk00001.dat
#
# parsed transaction 36 for block 3 file blocks_demo/blk00000.datparsed transaction 74 for block 3 file blocks_demo/blk00001.dat
#
# wrote transaction 36 for block 3 file blocks_demo/blk00000.dat
# wrote transaction 74 for block 3 file blocks_demo/blk00001.dat
# parsed transaction 75 for block 3 file blocks_demo/blk00001.datparsed transaction 37 for block 3 file blocks_demo/blk00000.dat
#
# wrote transaction 37 for block 3 file blocks_demo/blk00000.datwrote transaction 75 for block 3 file blocks_demo/blk00001.dat
#
# parsed transaction 76 for block 3 file blocks_demo/blk00001.datparsed transaction 38 for block 3 file blocks_demo/blk00000.dat
#
# wrote transaction 38 for block 3 file blocks_demo/blk00000.datwrote transaction 76 for block 3 file blocks_demo/blk00001.dat
#
# parsed transaction 39 for block 3 file blocks_demo/blk00000.dat
# parsed transaction 77 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 39 for block 3 file blocks_demo/blk00000.dat
# wrote transaction 77 for block 3 file blocks_demo/blk00001.dat
# parsed transaction 40 for block 3 file blocks_demo/blk00000.dat
# parsed transaction 78 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 40 for block 3 file blocks_demo/blk00000.datwrote transaction 78 for block 3 file blocks_demo/blk00001.dat
#
# parsed transaction 79 for block 3 file blocks_demo/blk00001.dat
# parsed transaction 41 for block 3 file blocks_demo/blk00000.dat
# wrote transaction 79 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 41 for block 3 file blocks_demo/blk00000.dat
# parsed transaction 42 for block 3 file blocks_demo/blk00000.dat
# parsed transaction 80 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 80 for block 3 file blocks_demo/blk00001.datwrote transaction 42 for block 3 file blocks_demo/blk00000.dat
#
# parsed transaction 43 for block 3 file blocks_demo/blk00000.dat
# parsed transaction 81 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 43 for block 3 file blocks_demo/blk00000.datwrote transaction 81 for block 3 file blocks_demo/blk00001.dat
#
# parsed transaction 82 for block 3 file blocks_demo/blk00001.dat
# parsed transaction 44 for block 3 file blocks_demo/blk00000.dat
# wrote transaction 82 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 44 for block 3 file blocks_demo/blk00000.dat
# parsed transaction 83 for block 3 file blocks_demo/blk00001.dat
# parsed transaction 45 for block 3 file blocks_demo/blk00000.dat
# wrote transaction 83 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 45 for block 3 file blocks_demo/blk00000.dat
# parsed transaction 84 for block 3 file blocks_demo/blk00001.dat
# parsed transaction 46 for block 3 file blocks_demo/blk00000.dat
# wrote transaction 84 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 46 for block 3 file blocks_demo/blk00000.dat
# parsed transaction 85 for block 3 file blocks_demo/blk00001.dat
# parsed transaction 47 for block 3 file blocks_demo/blk00000.dat
# wrote transaction 85 for block 3 file blocks_demo/blk00001.dat
# parsed transaction 86 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 47 for block 3 file blocks_demo/blk00000.dat
# parsed transaction 48 for block 3 file blocks_demo/blk00000.dat
# wrote transaction 86 for block 3 file blocks_demo/blk00001.dat
# parsed transaction 87 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 48 for block 3 file blocks_demo/blk00000.dat
# parsed transaction 49 for block 3 file blocks_demo/blk00000.dat
# wrote transaction 87 for block 3 file blocks_demo/blk00001.dat
# parsed transaction 88 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 49 for block 3 file blocks_demo/blk00000.dat
# parsed transaction 50 for block 3 file blocks_demo/blk00000.dat
# wrote transaction 88 for block 3 file blocks_demo/blk00001.dat
# parsed transaction 89 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 50 for block 3 file blocks_demo/blk00000.dat
# parsed transaction 51 for block 3 file blocks_demo/blk00000.dat
# wrote transaction 89 for block 3 file blocks_demo/blk00001.dat
# parsed transaction 90 for block 3 file blocks_demo/blk00001.datwrote transaction 51 for block 3 file blocks_demo/blk00000.dat
#
# parsed transaction 52 for block 3 file blocks_demo/blk00000.dat
# wrote transaction 90 for block 3 file blocks_demo/blk00001.dat
# parsed transaction 91 for block 3 file blocks_demo/blk00001.datwrote transaction 52 for block 3 file blocks_demo/blk00000.dat
#
# parsed transaction 53 for block 3 file blocks_demo/blk00000.dat
# wrote transaction 91 for block 3 file blocks_demo/blk00001.dat
# parsed transaction 92 for block 3 file blocks_demo/blk00001.datwrote transaction 53 for block 3 file blocks_demo/blk00000.dat
#
# parsed transaction 54 for block 3 file blocks_demo/blk00000.dat
# wrote transaction 92 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 54 for block 3 file blocks_demo/blk00000.dat
# parsed transaction 93 for block 3 file blocks_demo/blk00001.dat
# parsed transaction 55 for block 3 file blocks_demo/blk00000.dat
# wrote transaction 93 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 55 for block 3 file blocks_demo/blk00000.dat
# parsed transaction 94 for block 3 file blocks_demo/blk00001.dat
# parsed transaction 56 for block 3 file blocks_demo/blk00000.dat
# wrote transaction 94 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 56 for block 3 file blocks_demo/blk00000.dat
# parsed transaction 95 for block 3 file blocks_demo/blk00001.dat
# parsed transaction 57 for block 3 file blocks_demo/blk00000.dat
# wrote transaction 95 for block 3 file blocks_demo/blk00001.dat
# wrote transaction 57 for block 3 file blocks_demo/blk00000.dat
# parsed block 4 file blocks_demo/blk00001.datparsed transaction 58 for block 3 file blocks_demo/blk00000.dat
#
# wrote block 4 file blocks_demo/blk00001.dat
# parsed transaction 0 for block 4 file blocks_demo/blk00001.dat
# ...
# parsed transaction 56 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 56 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 57 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 57 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 58 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 58 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 59 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 59 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 60 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 60 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 61 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 61 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 62 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 62 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 63 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 63 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 64 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 64 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 65 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 65 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 66 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 66 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 67 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 67 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 68 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 68 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 69 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 69 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 70 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 70 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 71 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 71 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 72 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 72 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 73 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 73 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 74 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 74 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 75 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 75 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 76 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 76 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 77 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 77 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 78 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 78 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 79 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 79 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 80 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 80 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 81 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 81 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 82 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 82 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 83 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 83 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 84 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 84 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 85 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 85 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 86 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 86 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 87 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 87 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 88 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 88 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 89 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 89 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 90 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 90 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 91 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 91 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 92 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 92 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 93 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 93 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 94 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 94 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 95 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 95 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 96 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 96 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 97 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 97 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 98 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 98 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 99 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 99 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 100 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 100 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 101 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 101 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 102 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 102 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 103 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 103 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 104 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 104 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 105 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 105 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 106 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 106 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 107 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 107 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 108 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 108 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 109 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 109 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 110 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 110 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 111 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 111 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 112 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 112 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 113 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 113 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 114 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 114 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 115 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 115 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 116 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 116 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 117 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 117 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 118 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 118 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 119 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 119 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 120 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 120 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 121 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 121 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 122 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 122 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 123 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 123 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 124 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 124 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 125 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 125 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 126 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 126 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 127 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 127 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 128 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 128 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 129 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 129 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 130 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 130 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 131 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 131 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 132 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 132 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 133 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 133 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 134 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 134 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 135 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 135 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 136 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 136 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 137 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 137 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 138 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 138 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 139 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 139 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 140 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 140 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 141 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 141 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 142 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 142 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 143 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 143 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 144 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 144 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 145 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 145 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 146 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 146 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 147 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 147 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 148 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 148 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 149 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 149 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 150 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 150 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 151 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 151 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 152 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 152 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 153 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 153 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 154 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 154 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 155 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 155 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 156 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 156 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 157 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 157 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 158 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 158 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 159 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 159 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 160 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 160 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 161 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 161 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 162 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 162 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 163 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 163 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 164 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 164 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 165 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 165 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 166 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 166 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 167 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 167 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 168 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 168 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 169 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 169 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 170 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 170 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 171 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 171 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 172 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 172 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 173 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 173 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 174 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 174 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 175 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 175 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 176 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 176 for block 19 file blocks_demo/blk00001.dat
# parsed transaction 177 for block 19 file blocks_demo/blk00001.dat
# wrote transaction 177 for block 19 file blocks_demo/blk00001.dat
# Finished blk00020 file.
#
# <built-in method with_traceback of Exception object at 0x10d7a8ba0>

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-25-01fe5fe42e28> in <module>
# ----> 1 with open("blocks_demo/blk00000.dat") as blockfile:
#       2     try:
#       3         with open("blocks_demo/blk00000.txt") as coursor:
#       4             print(coursor.read(10))
#       5     except:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'blocks_demo/blk00000.dat'

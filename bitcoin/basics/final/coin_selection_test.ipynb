# %%
from coin_selector import get_coins_ready

# %%
utxos = [("a","a",3764),("b","b",25397),("c","c",3467),("d","d",4503),("e","e",23666),("f","f",11834),("g","g",222222),
         ("h","h",403123),("i","i",59987),("o","o",7030123),("p","p",5901987),("q","q",1030123),("r","r",909987),
         ("j","j",100000),("k","k",33287),("l","l",44237),("m","m",19934),("n","n",38906)]

# %%
coins = get_coins_ready(utxos, 879362, 1) 
coins
# Out:
# utxos [('a', 'a', 3764), ('b', 'b', 25397), ('c', 'c', 3467), ('d', 'd', 4503), ('e', 'e', 23666), ('f', 'f', 11834), ('g', 'g', 222222), ('h', 'h', 403123), ('i', 'i', 59987), ('o', 'o', 7030123), ('p', 'p', 5901987), ('q', 'q', 1030123), ('r', 'r', 909987), ('j', 'j', 100000), ('k', 'k', 33287), ('l', 'l', 44237), ('m', 'm', 19934), ('n', 'n', 38906)]
# total_out 879362
# n_outputs1
# avg: 879362, fake_total_out: 1758724, total_utxos: 15866547
# total_utxos is greater
# i,candidate : 0, ('q', 'q', 1030123)
# test_total : 1904314
# created tx with hidden change.
# {'utxos': [('r', 'r', 909987),
#   ('h', 'h', 403123),
#   ('g', 'g', 222222),
#   ('j', 'j', 100000),
#   ('i', 'i', 59987),
#   ('l', 'l', 44237),
#   ('n', 'n', 38906),
#   ('k', 'k', 33287),
#   ('b', 'b', 25397),
#   ('e', 'e', 23666),
#   ('m', 'm', 19934),
#   ('f', 'f', 11834),
#   ('d', 'd', 4503),
#   ('a', 'a', 3764),
#   ('c', 'c', 3467)],
#  'fee': 160006,
#  'change': 864946}

# %%
if coins["change"]: print("ok")
# Out:
# ok

# %%
import random

# %%
amounts = [random.randrange(4444,9999999) for x in range(100)]

# %%
amounts[:10]
# Out:
# [4309464,
#  5467602,
#  5654319,
#  9466903,
#  6309236,
#  1976326,
#  4894383,
#  9975825,
#  8680026,
#  1986966]

# %%
for amount in amounts: print(f"\n{get_coins_change(utxos, amount, 1)}\n")
# Out:
# utxos [('a', 'a', 3764), ('b', 'b', 25397), ('c', 'c', 3467), ('d', 'd', 4503), ('e', 'e', 23666), ('f', 'f', 11834), ('g', 'g', 222222), ('h', 'h', 403123), ('i', 'i', 59987), ('o', 'o', 7030123), ('p', 'p', 5901987), ('q', 'q', 1030123), ('r', 'r', 909987), ('j', 'j', 100000), ('k', 'k', 33287), ('l', 'l', 44237), ('m', 'm', 19934), ('n', 'n', 38906)]
# total_out 4309464
# n_outputs1
# avg: 4309464, fake_total_out: 8618928, total_utxos: 15866547
# total_utxos is greater
# i,candidate : 0, ('c', 'c', 3467)
# test_total : 15863080
# diff : 3651708.0
# created tx with hidden change.
#
# {'utxos': [('c', 'c', 3467), ('d', 'd', 4503), ('f', 'f', 11834), ('m', 'm', 19934), ('e', 'e', 23666), ('b', 'b', 25397), ('k', 'k', 33287), ('n', 'n', 38906), ('l', 'l', 44237), ('i', 'i', 59987), ('j', 'j', 100000), ('g', 'g', 222222), ('h', 'h', 403123), ('r', 'r', 909987), ('q', 'q', 1030123), ('p', 'p', 5901987), ('o', 'o', 7030123)], 'fee': 180446, 'change': 11372873}
#
# ...

# %%
a =True
b = None
if a and not b: print("ok")
# Out:
# ok
